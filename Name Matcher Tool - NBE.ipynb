# %% [markdown]
# # <font size="8">Install Required Packages</font>

# %% [markdown]
# ## Packages

# %%
# !pip install pandas transformers unidecode transliterate langdetect metaphone gradio
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Collecting transliterate
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl.metadata (14 kB)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting metaphone
#   Downloading Metaphone-0.6.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio
#   Downloading gradio-5.3.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: six>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from transliterate) (1.16.0)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.3-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.4.2 (from gradio)
#   Downloading gradio_client-1.4.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers)
#   Downloading huggingface_hub-0.26.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 258.0 kB/s eta 0:00:00
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.9.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.7.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.41.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.4.2->gradio) (2024.6.1)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.2->gradio)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 17.4 MB/s eta 0:00:00
# Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.6 MB/s eta 0:00:00
# Downloading gradio-5.3.0-py3-none-any.whl (56.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 8.1 MB/s eta 0:00:00
# Downloading gradio_client-1.4.2-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 19.1 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.3-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 5.7 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 7.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.1-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 23.1 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading orjson-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 13.0 MB/s eta 0:00:00
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading ruff-0.7.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 54.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.41.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.9 MB/s eta 0:00:00
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.7 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.0 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect, metaphone
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=5937d63338e3615790319b7dfefce86c17047bd98b7007b9409c6290b93734aa
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for metaphone (setup.py) ... done
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13901 sha256=452fd6bd418424d95356e11ad0ca35d1c3aa8f4a87a18a095ab2ecc4531ce7b3
#   Stored in directory: /root/.cache/pip/wheels/23/dd/1d/6cdd346605db62bde1f60954155e9ce48f4681c243f265b704
# Successfully built langdetect metaphone
# Installing collected packages: pydub, metaphone, websockets, unidecode, transliterate, tomlkit, semantic-version, ruff, python-multipart, orjson, markupsafe, langdetect, h11, ffmpy, aiofiles, uvicorn, starlette, huggingface-hub, httpcore, httpx, fastapi, gradio-client, gradio
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.7
#     Uninstalling huggingface-hub-0.24.7:
#       Successfully uninstalled huggingface-hub-0.24.7
# Successfully installed aiofiles-23.2.1 fastapi-0.115.3 ffmpy-0.4.0 gradio-5.3.0 gradio-client-1.4.2 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 huggingface-hub-0.26.1 langdetect-1.0.9 markupsafe-2.1.5 metaphone-0.6 orjson-3.10.10 pydub-0.25.1 python-multipart-0.0.12 ruff-0.7.1 semantic-version-2.10.0 starlette-0.41.0 tomlkit-0.12.0 transliterate-1.10.2 unidecode-1.3.8 uvicorn-0.32.0 websockets-12.0

# %% [markdown]
# ## Install Arabic Transliterator

# %%
# !git clone https://github.com/MTG/ArabicTransliterator.git
# Out:
# Cloning into 'ArabicTransliterator'...
# remote: Enumerating objects: 659, done.
# remote: Total 659 (delta 0), reused 0 (delta 0), pack-reused 659 (from 1)
# Receiving objects: 100% (659/659), 22.03 MiB | 11.48 MiB/s, done.
# Resolving deltas: 100% (369/369), done.
# Updating files: 100% (210/210), done.

# %%
# %cd ArabicTransliterator
# !python3 setup.py install
# !pip3 install -e .
#Renaming file to avoid duplications
# !mv ArabicTransliterator.py transliterator.py
# Out:
# /content/ArabicTransliterator
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating arabictransliterator.egg-info
# writing arabictransliterator.egg-info/PKG-INFO
# writing dependency_links to arabictransliterator.egg-info/dependency_links.txt
# writing top-level names to arabictransliterator.egg-info/top_level.txt
# writing manifest file 'arabictransliterator.egg-info/SOURCES.txt'
# reading manifest file 'arabictransliterator.egg-info/SOURCES.txt'
# writing manifest file 'arabictransliterator.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/lib/aranasyn
# copying aranasyn/syn_const.py -> build/lib/aranasyn
# copying aranasyn/synnode.py -> build/lib/aranasyn
# copying aranasyn/anasyn.py -> build/lib/aranasyn
# copying aranasyn/anasyn2.py -> build/lib/aranasyn
# copying aranasyn/__init__.py -> build/lib/aranasyn
# copying aranasyn/stemmedsynword.py -> build/lib/aranasyn
# copying aranasyn/anasynDirect.py -> build/lib/aranasyn
# creating build/lib/arramooz
# copying arramooz/stopwordsdictionaryclass.py -> build/lib/arramooz
# copying arramooz/wordfreqdictionaryclass.py -> build/lib/arramooz
# copying arramooz/__init__.py -> build/lib/arramooz
# copying arramooz/arabicdictionary.py -> build/lib/arramooz
# creating build/lib/asmai
# copying asmai/sem_const2.py -> build/lib/asmai
# copying asmai/collocationdictionary.py -> build/lib/asmai
# copying asmai/__init__.py -> build/lib/asmai
# copying asmai/semcollocationdictionary.py -> build/lib/asmai
# copying asmai/sem_const.py -> build/lib/asmai
# copying asmai/anasem.py -> build/lib/asmai
# creating build/lib/collocations
# copying collocations/collocations.py -> build/lib/collocations
# copying collocations/collocation_const.py -> build/lib/collocations
# copying collocations/collocations.old.py -> build/lib/collocations
# copying collocations/collocationdictionary.py -> build/lib/collocations
# copying collocations/__init__.py -> build/lib/collocations
# creating build/lib/collocations/pyarabic
# copying collocations/pyarabic/propernouns.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/number.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/arabrepr.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/stack.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/araby2.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/named.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/araby.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/__init__.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/named_const.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/unshape.py -> build/lib/collocations/pyarabic
# copying collocations/pyarabic/number_const.py -> build/lib/collocations/pyarabic
# creating build/lib/mishkal
# copying mishkal/__init__.py -> build/lib/mishkal
# creating build/lib/mishkal/tashkeel
# copying mishkal/tashkeel/tashkeel_const.py -> build/lib/mishkal/tashkeel
# copying mishkal/tashkeel/testNamed.py -> build/lib/mishkal/tashkeel
# copying mishkal/tashkeel/tashkeel.py -> build/lib/mishkal/tashkeel
# copying mishkal/tashkeel/__init__.py -> build/lib/mishkal/tashkeel
# creating build/lib/pyarabic
# copying pyarabic/propernouns.py -> build/lib/pyarabic
# copying pyarabic/number.py -> build/lib/pyarabic
# copying pyarabic/arabrepr.py -> build/lib/pyarabic
# copying pyarabic/stack.py -> build/lib/pyarabic
# copying pyarabic/araby2.py -> build/lib/pyarabic
# copying pyarabic/named.py -> build/lib/pyarabic
# copying pyarabic/araby.py -> build/lib/pyarabic
# copying pyarabic/__init__.py -> build/lib/pyarabic
# copying pyarabic/harf.py -> build/lib/pyarabic
# copying pyarabic/named_const.py -> build/lib/pyarabic
# copying pyarabic/unshape.py -> build/lib/pyarabic
# copying pyarabic/number_const.py -> build/lib/pyarabic
# creating build/lib/naftawayh
# copying naftawayh/ar_ctype.py -> build/lib/naftawayh
# copying naftawayh/stopwords.py -> build/lib/naftawayh
# copying naftawayh/specialwords.py -> build/lib/naftawayh
# copying naftawayh/affix_const.py -> build/lib/naftawayh
# copying naftawayh/create_verbstamp.py -> build/lib/naftawayh
# copying naftawayh/verb_dictionary.py -> build/lib/naftawayh
# copying naftawayh/arabic_const.py -> build/lib/naftawayh
# copying naftawayh/verb_stamp.py -> build/lib/naftawayh
# copying naftawayh/__init__.py -> build/lib/naftawayh
# copying naftawayh/wordtag.py -> build/lib/naftawayh
# copying naftawayh/ar_stopwords.py -> build/lib/naftawayh
# copying naftawayh/ar_stowords.py -> build/lib/naftawayh
# copying naftawayh/wordtag_const.py -> build/lib/naftawayh
# creating build/lib/tashaphyne
# copying tashaphyne/stemming.py -> build/lib/tashaphyne
# copying tashaphyne/stemming.old.py -> build/lib/tashaphyne
# copying tashaphyne/stem_const.py -> build/lib/tashaphyne
# copying tashaphyne/arabic_const.py -> build/lib/tashaphyne
# copying tashaphyne/normalize.py -> build/lib/tashaphyne
# copying tashaphyne/__init__.py -> build/lib/tashaphyne
# creating build/lib/qalsadi
# copying qalsadi/analex_const.py -> build/lib/qalsadi
# copying qalsadi/stemmedaffix.py -> build/lib/qalsadi
# copying qalsadi/stopwords.py -> build/lib/qalsadi
# copying qalsadi/stem_pounct_const.py -> build/lib/qalsadi
# copying qalsadi/stem_stopwords.py -> build/lib/qalsadi
# copying qalsadi/stem_unknown.py -> build/lib/qalsadi
# copying qalsadi/disambig_const.py -> build/lib/qalsadi
# copying qalsadi/test.py -> build/lib/qalsadi
# copying qalsadi/stem_verb_const.py -> build/lib/qalsadi
# copying qalsadi/stem_noun.py -> build/lib/qalsadi
# copying qalsadi/__init__.py -> build/lib/qalsadi
# copying qalsadi/disambig.py -> build/lib/qalsadi
# copying qalsadi/stem_verb.py -> build/lib/qalsadi
# copying qalsadi/analex.py -> build/lib/qalsadi
# copying qalsadi/cache.py -> build/lib/qalsadi
# copying qalsadi/stemmedword.py -> build/lib/qalsadi
# copying qalsadi/stem_noun_const.py -> build/lib/qalsadi
# copying qalsadi/stem_unknown_const.py -> build/lib/qalsadi
# copying qalsadi/wordCase.py -> build/lib/qalsadi
# copying qalsadi/dictword.py -> build/lib/qalsadi
# creating build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/_س_س_خ _ز_س ar_verb.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/ar_ctype.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/stack.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/conjugate.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/alefmaddaverbtable.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/arabic_const.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/__init__.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/conjugatedisplay.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/mosaref_main.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/verb_const.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/ar_verb.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/triverbtable.py -> build/lib/qalsadi/libqutrub
# copying qalsadi/libqutrub/classverb.py -> build/lib/qalsadi/libqutrub
# creating build/lib/arabic
# copying ./__init__.py -> build/lib/arabic
# copying ./ArabicTransliterator.py -> build/lib/arabic
# copying ./arabic_reshaper.py -> build/lib/arabic
# creating build/lib/CodernityDB
# copying CodernityDB/storage.py -> build/lib/CodernityDB
# copying CodernityDB/lfu_cache.py -> build/lib/CodernityDB
# copying CodernityDB/sharded_hash.py -> build/lib/CodernityDB
# copying CodernityDB/rr_cache.py -> build/lib/CodernityDB
# copying CodernityDB/indexcreator.py -> build/lib/CodernityDB
# copying CodernityDB/database_gevent.py -> build/lib/CodernityDB
# copying CodernityDB/database_thread_safe.py -> build/lib/CodernityDB
# copying CodernityDB/patch.py -> build/lib/CodernityDB
# copying CodernityDB/env.py -> build/lib/CodernityDB
# copying CodernityDB/migrate.py -> build/lib/CodernityDB
# copying CodernityDB/__init__.py -> build/lib/CodernityDB
# copying CodernityDB/database_super_thread_safe.py -> build/lib/CodernityDB
# copying CodernityDB/misc.py -> build/lib/CodernityDB
# copying CodernityDB/lfu_cache_with_lock.py -> build/lib/CodernityDB
# copying CodernityDB/index.py -> build/lib/CodernityDB
# copying CodernityDB/sharded_index.py -> build/lib/CodernityDB
# copying CodernityDB/debug_stuff.py -> build/lib/CodernityDB
# copying CodernityDB/tree_index.py -> build/lib/CodernityDB
# copying CodernityDB/database.py -> build/lib/CodernityDB
# copying CodernityDB/database_safe_shared.py -> build/lib/CodernityDB
# copying CodernityDB/rr_cache_with_lock.py -> build/lib/CodernityDB
# copying CodernityDB/hash_index.py -> build/lib/CodernityDB
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'arramooz.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'arramooz.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'arramooz.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'arramooz.data' to be distributed and are
#         already explicitly excluding 'arramooz.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.10/dist-packages/setuptools/command/build_py.py:218: _Warning: Package 'collocations.data' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'collocations.data' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'collocations.data' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'collocations.data' to be distributed and are
#         already explicitly excluding 'collocations.data' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# creating build/lib/arramooz/data
# copying arramooz/data/arabicdictionary.sqlite -> build/lib/arramooz/data
# copying arramooz/data/arabicdictionary.sqlite.bz2 -> build/lib/arramooz/data
# copying arramooz/data/nouns_sqliteStructure.sql -> build/lib/arramooz/data
# copying arramooz/data/randomtext.txt -> build/lib/arramooz/data
# copying arramooz/data/stopwords.sql -> build/lib/arramooz/data
# copying arramooz/data/stopwords.sqlite -> build/lib/arramooz/data
# copying arramooz/data/stopwords.sqlite.old -> build/lib/arramooz/data
# copying arramooz/data/verbs.dict.sqliteStructure.sql -> build/lib/arramooz/data
# copying arramooz/data/wordfreq.sqlite -> build/lib/arramooz/data
# copying arramooz/data/wordfreq.sqlite.bz2 -> build/lib/arramooz/data
# copying arramooz/data/wordfreq.sqliteStructure.sql -> build/lib/arramooz/data
# copying collocations/collocations.old.py -> build/lib/collocations
# creating build/lib/collocations/data
# copying collocations/data/collocations.sqlite -> build/lib/collocations/data
# copying tashaphyne/stemming.old.py -> build/lib/tashaphyne
# copying qalsadi/libqutrub/_س_س_خ _ز_س ar_verb.py -> build/lib/qalsadi/libqutrub
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/arramooz
# copying build/lib/arramooz/stopwordsdictionaryclass.py -> build/bdist.linux-x86_64/egg/arramooz
# copying build/lib/arramooz/wordfreqdictionaryclass.py -> build/bdist.linux-x86_64/egg/arramooz
# copying build/lib/arramooz/__init__.py -> build/bdist.linux-x86_64/egg/arramooz
# copying build/lib/arramooz/arabicdictionary.py -> build/bdist.linux-x86_64/egg/arramooz
# creating build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/wordfreq.sqlite.bz2 -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/stopwords.sqlite -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/arabicdictionary.sqlite.bz2 -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/stopwords.sqlite.old -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/stopwords.sql -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/arabicdictionary.sqlite -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/verbs.dict.sqliteStructure.sql -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/wordfreq.sqliteStructure.sql -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/nouns_sqliteStructure.sql -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/randomtext.txt -> build/bdist.linux-x86_64/egg/arramooz/data
# copying build/lib/arramooz/data/wordfreq.sqlite -> build/bdist.linux-x86_64/egg/arramooz/data
# creating build/bdist.linux-x86_64/egg/mishkal
# creating build/bdist.linux-x86_64/egg/mishkal/tashkeel
# copying build/lib/mishkal/tashkeel/tashkeel_const.py -> build/bdist.linux-x86_64/egg/mishkal/tashkeel
# copying build/lib/mishkal/tashkeel/testNamed.py -> build/bdist.linux-x86_64/egg/mishkal/tashkeel
# copying build/lib/mishkal/tashkeel/tashkeel.py -> build/bdist.linux-x86_64/egg/mishkal/tashkeel
# copying build/lib/mishkal/tashkeel/__init__.py -> build/bdist.linux-x86_64/egg/mishkal/tashkeel
# copying build/lib/mishkal/__init__.py -> build/bdist.linux-x86_64/egg/mishkal
# creating build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/storage.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/lfu_cache.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/sharded_hash.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/rr_cache.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/indexcreator.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/database_gevent.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/database_thread_safe.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/patch.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/env.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/migrate.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/__init__.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/database_super_thread_safe.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/misc.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/lfu_cache_with_lock.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/index.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/sharded_index.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/debug_stuff.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/tree_index.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/database.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/database_safe_shared.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/rr_cache_with_lock.py -> build/bdist.linux-x86_64/egg/CodernityDB
# copying build/lib/CodernityDB/hash_index.py -> build/bdist.linux-x86_64/egg/CodernityDB
# creating build/bdist.linux-x86_64/egg/collocations
# copying build/lib/collocations/collocations.py -> build/bdist.linux-x86_64/egg/collocations
# copying build/lib/collocations/collocation_const.py -> build/bdist.linux-x86_64/egg/collocations
# copying build/lib/collocations/collocations.old.py -> build/bdist.linux-x86_64/egg/collocations
# copying build/lib/collocations/collocationdictionary.py -> build/bdist.linux-x86_64/egg/collocations
# copying build/lib/collocations/__init__.py -> build/bdist.linux-x86_64/egg/collocations
# creating build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/propernouns.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/number.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/arabrepr.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/stack.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/araby2.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/named.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/araby.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/__init__.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/named_const.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/unshape.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# copying build/lib/collocations/pyarabic/number_const.py -> build/bdist.linux-x86_64/egg/collocations/pyarabic
# creating build/bdist.linux-x86_64/egg/collocations/data
# copying build/lib/collocations/data/collocations.sqlite -> build/bdist.linux-x86_64/egg/collocations/data
# creating build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/stemming.py -> build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/stemming.old.py -> build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/stem_const.py -> build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/arabic_const.py -> build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/normalize.py -> build/bdist.linux-x86_64/egg/tashaphyne
# copying build/lib/tashaphyne/__init__.py -> build/bdist.linux-x86_64/egg/tashaphyne
# creating build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/ar_ctype.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/stopwords.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/specialwords.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/affix_const.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/create_verbstamp.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/verb_dictionary.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/arabic_const.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/verb_stamp.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/__init__.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/wordtag.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/ar_stopwords.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/ar_stowords.py -> build/bdist.linux-x86_64/egg/naftawayh
# copying build/lib/naftawayh/wordtag_const.py -> build/bdist.linux-x86_64/egg/naftawayh
# creating build/bdist.linux-x86_64/egg/arabic
# copying build/lib/arabic/__init__.py -> build/bdist.linux-x86_64/egg/arabic
# copying build/lib/arabic/ArabicTransliterator.py -> build/bdist.linux-x86_64/egg/arabic
# copying build/lib/arabic/arabic_reshaper.py -> build/bdist.linux-x86_64/egg/arabic
# creating build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/sem_const2.py -> build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/collocationdictionary.py -> build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/__init__.py -> build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/semcollocationdictionary.py -> build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/sem_const.py -> build/bdist.linux-x86_64/egg/asmai
# copying build/lib/asmai/anasem.py -> build/bdist.linux-x86_64/egg/asmai
# creating build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/syn_const.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/synnode.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/anasyn.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/anasyn2.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/__init__.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/stemmedsynword.py -> build/bdist.linux-x86_64/egg/aranasyn
# copying build/lib/aranasyn/anasynDirect.py -> build/bdist.linux-x86_64/egg/aranasyn
# creating build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/propernouns.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/number.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/arabrepr.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/stack.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/araby2.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/named.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/araby.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/__init__.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/harf.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/named_const.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/unshape.py -> build/bdist.linux-x86_64/egg/pyarabic
# copying build/lib/pyarabic/number_const.py -> build/bdist.linux-x86_64/egg/pyarabic
# creating build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/analex_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stemmedaffix.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stopwords.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_pounct_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_stopwords.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_unknown.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/disambig_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/test.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_verb_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_noun.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/__init__.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/disambig.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_verb.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/analex.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/cache.py -> build/bdist.linux-x86_64/egg/qalsadi
# creating build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/_س_س_خ _ز_س ar_verb.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/ar_ctype.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/stack.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/conjugate.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/alefmaddaverbtable.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/arabic_const.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/__init__.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/conjugatedisplay.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/mosaref_main.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/verb_const.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/ar_verb.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/triverbtable.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/libqutrub/classverb.py -> build/bdist.linux-x86_64/egg/qalsadi/libqutrub
# copying build/lib/qalsadi/stemmedword.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_noun_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/stem_unknown_const.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/wordCase.py -> build/bdist.linux-x86_64/egg/qalsadi
# copying build/lib/qalsadi/dictword.py -> build/bdist.linux-x86_64/egg/qalsadi
# byte-compiling build/bdist.linux-x86_64/egg/arramooz/stopwordsdictionaryclass.py to stopwordsdictionaryclass.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arramooz/wordfreqdictionaryclass.py to wordfreqdictionaryclass.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arramooz/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arramooz/arabicdictionary.py to arabicdictionary.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mishkal/tashkeel/tashkeel_const.py to tashkeel_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mishkal/tashkeel/testNamed.py to testNamed.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mishkal/tashkeel/tashkeel.py to tashkeel.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mishkal/tashkeel/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mishkal/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/storage.py to storage.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/lfu_cache.py to lfu_cache.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/sharded_hash.py to sharded_hash.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/rr_cache.py to rr_cache.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/indexcreator.py to indexcreator.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/database_gevent.py to database_gevent.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/database_thread_safe.py to database_thread_safe.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/patch.py to patch.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/env.py to env.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/migrate.py to migrate.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/database_super_thread_safe.py to database_super_thread_safe.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/misc.py to misc.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/lfu_cache_with_lock.py to lfu_cache_with_lock.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/index.py to index.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/sharded_index.py to sharded_index.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/debug_stuff.py to debug_stuff.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/tree_index.py to tree_index.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/database.py to database.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/database_safe_shared.py to database_safe_shared.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/rr_cache_with_lock.py to rr_cache_with_lock.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/CodernityDB/hash_index.py to hash_index.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/collocations.py to collocations.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/collocation_const.py to collocation_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/collocations.old.py to collocations.old.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/collocationdictionary.py to collocationdictionary.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/propernouns.py to propernouns.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/number.py to number.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/arabrepr.py to arabrepr.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/stack.py to stack.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/araby2.py to araby2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/named.py to named.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/araby.py to araby.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/named_const.py to named_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/unshape.py to unshape.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/collocations/pyarabic/number_const.py to number_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/stemming.py to stemming.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/stemming.old.py to stemming.old.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/stem_const.py to stem_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/arabic_const.py to arabic_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/normalize.py to normalize.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/tashaphyne/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/ar_ctype.py to ar_ctype.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/stopwords.py to stopwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/specialwords.py to specialwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/affix_const.py to affix_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/create_verbstamp.py to create_verbstamp.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/verb_dictionary.py to verb_dictionary.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/arabic_const.py to arabic_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/verb_stamp.py to verb_stamp.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/wordtag.py to wordtag.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/ar_stopwords.py to ar_stopwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/ar_stowords.py to ar_stowords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/naftawayh/wordtag_const.py to wordtag_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arabic/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arabic/ArabicTransliterator.py to ArabicTransliterator.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/arabic/arabic_reshaper.py to arabic_reshaper.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/sem_const2.py to sem_const2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/collocationdictionary.py to collocationdictionary.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/semcollocationdictionary.py to semcollocationdictionary.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/sem_const.py to sem_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/asmai/anasem.py to anasem.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/syn_const.py to syn_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/synnode.py to synnode.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/anasyn.py to anasyn.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/anasyn2.py to anasyn2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/stemmedsynword.py to stemmedsynword.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/aranasyn/anasynDirect.py to anasynDirect.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/propernouns.py to propernouns.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/number.py to number.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/arabrepr.py to arabrepr.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/stack.py to stack.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/araby2.py to araby2.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/named.py to named.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/araby.py to araby.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/harf.py to harf.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/named_const.py to named_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/unshape.py to unshape.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyarabic/number_const.py to number_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/analex_const.py to analex_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stemmedaffix.py to stemmedaffix.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stopwords.py to stopwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_pounct_const.py to stem_pounct_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_stopwords.py to stem_stopwords.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_unknown.py to stem_unknown.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/disambig_const.py to disambig_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/test.py to test.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_verb_const.py to stem_verb_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_noun.py to stem_noun.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/disambig.py to disambig.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_verb.py to stem_verb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/analex.py to analex.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/cache.py to cache.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/_س_س_خ _ز_س ar_verb.py to _س_س_خ _ز_س ar_verb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/ar_ctype.py to ar_ctype.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/stack.py to stack.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/conjugate.py to conjugate.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/alefmaddaverbtable.py to alefmaddaverbtable.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/arabic_const.py to arabic_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/conjugatedisplay.py to conjugatedisplay.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/mosaref_main.py to mosaref_main.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/verb_const.py to verb_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/ar_verb.py to ar_verb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/triverbtable.py to triverbtable.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/libqutrub/classverb.py to classverb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stemmedword.py to stemmedword.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_noun_const.py to stem_noun_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/stem_unknown_const.py to stem_unknown_const.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/wordCase.py to wordCase.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/qalsadi/dictword.py to dictword.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying arabictransliterator.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying arabictransliterator.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying arabictransliterator.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying arabictransliterator.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# CodernityDB.__pycache__.database.cpython-310: module MAY be using inspect.getsource
# arramooz.__pycache__.arabicdictionary.cpython-310: module references __file__
# arramooz.__pycache__.stopwordsdictionaryclass.cpython-310: module references __file__
# arramooz.__pycache__.wordfreqdictionaryclass.cpython-310: module references __file__
# collocations.__pycache__.collocationdictionary.cpython-310: module references __file__
# creating dist
# creating 'dist/arabictransliterator-0.3-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing arabictransliterator-0.3-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/arabictransliterator-0.3-py3.10.egg
# Extracting arabictransliterator-0.3-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding arabictransliterator 0.3 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/arabictransliterator-0.3-py3.10.egg
# Processing dependencies for arabictransliterator==0.3
# Finished processing dependencies for arabictransliterator==0.3
# Obtaining file:///content/ArabicTransliterator
#   Preparing metadata (setup.py) ... done
# Installing collected packages: arabictransliterator
#   Attempting uninstall: arabictransliterator
#     Found existing installation: arabictransliterator 0.3
#     Uninstalling arabictransliterator-0.3:
#       Successfully uninstalled arabictransliterator-0.3
#   Running setup.py develop for arabictransliterator
# Successfully installed arabictransliterator-0.3

# %%
import ArabicTransliterator
from transliterator import ALA_LC_Transliterator
import mishkal.tashkeel.tashkeel as tashkeel
from text_unidecode import unidecode
#from pyarabic.araby import stripShadda, stripLastHaraka

transliterator = ALA_LC_Transliterator()

def transliterate_arabic(text, vocalize=True):
    voc = text
    if vocalize:
        vocalizer=tashkeel.TashkeelClass()
        voc = vocalizer.tashkeel(text)
        #voc = stripLastHaraka(stripShadda(vocalizer.tashkeel(text)))
    return unidecode(transliterator.do(voc.strip()))

# %% [markdown]
# ## Import BERT

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

# Load BERT tokenizer and model for English only
bert_model_name = "bert-base-uncased"  # English-only BERT model
bert_tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
bert_model = AutoModel.from_pretrained(bert_model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# # <font size="8">Transliteration</font>

# %% [markdown]
# ## Arabic Language

# %% [markdown]
# ### Normailizing Transliterator Output

# %%
def apply_rules_ar(input_text):
    # Split the input text into words
    words = input_text.split()

    # Process each word according to the specified rules
    processed_words = []
    for word in words:
        # Rule 1: If the word starts with the Arabic letter (ا), double it
        if word.startswith('ا') or word.startswith('ع'):
            word = 'ا' + word

        # Rule 2: If the word contains the Arabic letter (ذ), replace it with (ز)
        word = word.replace('ذ', 'ز')

        # Rule 3: If the word contains the Arabic letter (ع), replace it with (أ)
        word = word.replace('ع', 'أأ')

        # Add the processed word to the list
        processed_words.append(word)

    # Reconstruct the text by joining the processed words
    return ' '.join(processed_words)

# %%
import re

def normalize_text_ar(text):
    # Convert to lowercase
    text = text.lower()
    # Replace apostrophes with 'a'
    text = text.replace("'", "a")
    # Replace any double letter at the beginning of a word with a single instance
    text = re.sub(r'\b(\w)\1', r'\1', text)
    # Remove any remaining special characters or numbers
    text = re.sub(r"[^a-zA-Z\s']", '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %%
def transliterate_function_ar(text):
  return normalize_text_ar(transliterate_arabic(apply_rules_ar(text)))

# %% [markdown]
# ### Testing Transliterator

# %%
transliterate_function_ar('محمد هاني')
# Out:
# 'muhammad hani'

# %% [markdown]
# ## Latin Script Languages

# %% [markdown]
# ### Function

# %%
from unidecode import unidecode

# Direct transliteration functions for languages similar to English
def transliterate_direct(name):
    return unidecode(name)

# %%
# List of languages similar to English that don't need translation
languages_similar_to_english = {
    'es': 'Spanish',
    'pt': 'Portuguese',
    'fr': 'French',
    'it': 'Italian',
    'de': 'German',
    'nl': 'Dutch',
    'sv': 'Swedish',
    'da': 'Danish',
    'no': 'Norwegian',
    'ro': 'Romanian',
    'pl': 'Polish',
    'cs': 'Czech',
    'sk': 'Slovak',
    'hu': 'Hungarian',
    'tr': 'Turkish',
    'vi': 'Vietnamese',
    'ms': 'Malay',
    'id': 'Indonesian'
}

# %% [markdown]
# ### Test

# %%
# List of names with their languages and expected English versions
latin_with_translations = [
    ("José García", "Spanish", "Jose Garcia"),
    ("João Silva", "Portuguese", "Joao Silva"),
    ("François Dupont", "French", "Francois Dupont"),
    ("Giuseppe Rossi", "Italian", "Giuseppe Rossi"),
    ("Jürgen Müller", "German", "Jurgen Muller"),
    ("Maarten van Dijk", "Dutch", "Maarten van Dijk"),
    ("Björn Johansson", "Swedish", "Bjorn Johansson"),
    ("Søren Larsen", "Danish", "Soren Larsen"),
    ("Øyvind Hansen", "Norwegian", "Oyvind Hansen"),
    ("Ștefan Popescu", "Romanian", "Stefan Popescu"),
    ("Łukasz Nowak", "Polish", "Lukasz Nowak"),
    ("Jiří Novák", "Czech", "Jiri Novak"),
    ("Ľuboš Horváth", "Slovak", "Lubos Horvath"),
    ("Árpád Kovács", "Hungarian", "Arpad Kovacs"),
    ("Mehmet Yılmaz", "Turkish", "Mehmet Yilmaz"),
    ("Nguyễn Văn A", "Vietnamese", "Nguyen Van A"),
    ("Muhammad Amin", "Malay", "Muhammad Amin"),
    ("Putri Dewi", "Indonesian", "Putri Dewi")
]

# %%
import pandas as pd

# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
transliterated_outputs = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in latin_with_translations:
    transliterated_version = transliterate_direct(name)
    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    transliterated_outputs.append(transliterated_version)

# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Transliterated Output": transliterated_outputs
})

# %%
# Display the DataFrame
print(df)
# Out:
#       Language     Original Name  Expected English Transliterated Output
# 0      Spanish       José García       Jose Garcia           Jose Garcia
# 1   Portuguese        João Silva        Joao Silva            Joao Silva
# 2       French   François Dupont   Francois Dupont       Francois Dupont
# 3      Italian    Giuseppe Rossi    Giuseppe Rossi        Giuseppe Rossi
# 4       German     Jürgen Müller     Jurgen Muller         Jurgen Muller
# 5        Dutch  Maarten van Dijk  Maarten van Dijk      Maarten van Dijk
# 6      Swedish   Björn Johansson   Bjorn Johansson       Bjorn Johansson
# 7       Danish      Søren Larsen      Soren Larsen          Soren Larsen
# 8    Norwegian     Øyvind Hansen     Oyvind Hansen         Oyvind Hansen
# 9     Romanian    Ștefan Popescu    Stefan Popescu        Stefan Popescu
# 10      Polish      Łukasz Nowak      Lukasz Nowak          Lukasz Nowak
# 11       Czech        Jiří Novák        Jiri Novak            Jiri Novak
# 12      Slovak     Ľuboš Horváth     Lubos Horvath         Lubos Horvath
# 13   Hungarian      Árpád Kovács      Arpad Kovacs          Arpad Kovacs
# 14     Turkish     Mehmet Yılmaz     Mehmet Yilmaz         Mehmet Yilmaz
# 15  Vietnamese      Nguyễn Văn A      Nguyen Van A          Nguyen Van A
# 16       Malay     Muhammad Amin     Muhammad Amin         Muhammad Amin
# 17  Indonesian        Putri Dewi        Putri Dewi            Putri Dewi

# %% [markdown]
# ## Cyrillic Script Languages

# %% [markdown]
# ### Transliteration function

# %%
from transliterate import translit

# Transliterate for Cyrillic languages using transliterate library
def transliterate_cyrillic(name):
  '''
    try:
      # Transliterate the input name
      transliterated_name = translit(name, reversed=True)
      return unidecode(transliterated_name)
  '''
  return unidecode(name)

# %%
#List of cyrillic languagues
cyrillic_languagues = {
    'cyrillic': 'cyrillic script',
    'ru': 'Russian',
    'uk': 'Ukrainian',
    'bg': 'Bulgarian',
    'mn': 'Mongolian',
    'mk': 'Macedonian',
    'sr': 'Serbian',
    'el': 'Greek',
    'hy': 'Armenian'
}

# %% [markdown]
# ### Test

# %%
# List of names with their languages and expected English versions
cyrillic_with_translations = [
    ("Алексей Иванов", "Russian", "Aleksei Ivanov"),
    ("Олександр Шевченко", "Ukrainian", "Oleksandr Shevchenko"),
    ("Георги Петров", "Bulgarian", "Georgi Petrov"),
    ("Батбаяр Сэргэлэн", "Mongolian", "Batbayar Sergelen"),
    ("Александар Стојанов", "Macedonian", "Aleksandar Stojanov"),
    ("Никола Тесла", "Serbian", "Nikola Tesla"),
    ("Νικόλαος Παπαδόπουλος", "Greek", "Nikolaos Papadopoulos"),
    ("Արամ Մարտիրոսյան", "Armenian", "Aram Martirosyan")
]

# %%
# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
transliterated_outputs = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in cyrillic_with_translations:
    transliterated_version = transliterate_cyrillic(name)
    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    transliterated_outputs.append(transliterated_version)

# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Transliterated Output": transliterated_outputs
})

# %%
# Display the DataFrame
print(df)
# Out:
#      Language          Original Name       Expected English  \
# 0     Russian         Алексей Иванов         Aleksei Ivanov
# 1   Ukrainian     Олександр Шевченко   Oleksandr Shevchenko
# 2   Bulgarian          Георги Петров          Georgi Petrov
# 3   Mongolian       Батбаяр Сэргэлэн      Batbayar Sergelen
# 4  Macedonian    Александар Стојанов    Aleksandar Stojanov
# 5     Serbian           Никола Тесла           Nikola Tesla
# 6       Greek  Νικόλαος Παπαδόπουλος  Nikolaos Papadopoulos
# 7    Armenian       Արամ Մարտիրոսյան       Aram Martirosyan
#
#    Transliterated Output
# 0         Aleksei Ivanov
# 1   Oleksandr Shevchenko
# 2          Georgi Petrov
# 3      Batbaiar Sergelen
# 4    Aleksandar Stojanov
# 5           Nikola Tesla
# 6  Nikolaos Papadopoulos
# 7       Aram Martirosyan

# %% [markdown]
# ## Other Special Script Languages (Work in Progress)

# %%
# List of special languages with transliteration functions
special_languages = {
    'ar': 'Arabic',
}

unsupported_special_languages = {
    'zh': 'Chinese',
    'ko': 'Korean',
    'ja': 'Japanese',
    'hi': 'Hindi',
    'bn': 'Bengali'
}

# %%
'''
from pypinyin import pinyin, Style
from jamo import h2j, j2hcj
from korean_romanizer.romanizer import Romanizer
import romkan
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

# Transliteration functions

# Arabic
def transliterate_function_ar(name):
    # Transliterate Arabic name to Latin script
    return normalize_text_ar(transliterate_only(name))

# Chinese
def transliterate_function_zh(name):
    # Transliterate Chinese name to Pinyin without tone numbers
    pinyin_list = pinyin(name, style=Style.NORMAL)
    # Join the Pinyin list into a single string with spaces
    transliterated_name = ' '.join([''.join(word) for word in pinyin_list])
    return transliterated_name

# Korean
def transliterate_function_ko(name):
    # Use korean-romanizer to transliterate Korean to Latin script
    r = Romanizer(name)
    transliterated_name = r.romanize()
    return transliterated_name

# Japanese
def transliterate_function_ja(name):
    # Use romkan to transliterate Japanese Kana to Romaji
    transliterated_name = romkan.to_roma(name)
    return transliterated_name

# Hindi
def transliterate_function_hi(name):
    # Use indic_transliteration to transliterate Hindi to Latin script
    transliterated_name = transliterate(name, sanscript.DEVANAGARI, sanscript.ITRANS)
    return transliterated_name

# Bengali
def transliterate_function_bn(name):
    # Use indic_transliteration to transliterate Bengali to Latin script
    transliterated_name = transliterate(name, sanscript.BENGALI, sanscript.ITRANS)
    return transliterated_name

'''
# Out:
# "\nfrom pypinyin import pinyin, Style\nfrom jamo import h2j, j2hcj\nfrom korean_romanizer.romanizer import Romanizer\nimport romkan\nfrom indic_transliteration import sanscript\nfrom indic_transliteration.sanscript import transliterate\n\n# Transliteration functions\n\n# Arabic\ndef transliterate_function_ar(name):\n    # Transliterate Arabic name to Latin script\n    return normalize_text_ar(transliterate_only(name))\n\n# Chinese\ndef transliterate_function_zh(name):\n    # Transliterate Chinese name to Pinyin without tone numbers\n    pinyin_list = pinyin(name, style=Style.NORMAL)\n    # Join the Pinyin list into a single string with spaces\n    transliterated_name = ' '.join([''.join(word) for word in pinyin_list])\n    return transliterated_name\n\n# Korean\ndef transliterate_function_ko(name):\n    # Use korean-romanizer to transliterate Korean to Latin script\n    r = Romanizer(name)\n    transliterated_name = r.romanize()\n    return transliterated_name\n\n# Japanese\ndef transliterate_function_ja(name):\n    # Use romkan to transliterate Japanese Kana to Romaji\n    transliterated_name = romkan.to_roma(name)\n    return transliterated_name\n\n# Hindi\ndef transliterate_function_hi(name):\n    # Use indic_transliteration to transliterate Hindi to Latin script\n    transliterated_name = transliterate(name, sanscript.DEVANAGARI, sanscript.ITRANS)\n    return transliterated_name\n\n# Bengali\ndef transliterate_function_bn(name):\n    # Use indic_transliteration to transliterate Bengali to Latin script\n    transliterated_name = transliterate(name, sanscript.BENGALI, sanscript.ITRANS)\n    return transliterated_name\n\n"

# %%
# Special transliteration functions for languages not similar to English

def special_transliterate(name, language_code):
    # Define a dictionary mapping language codes to their respective transliteration functions
    transliteration_functions = {
        'ar': transliterate_function_ar  # Arabic
    }

    # Add more language codes and functions as needed
    '''
    'zh': transliterate_function_zh,  # Chinese
    'ko': transliterate_function_ko,  # Korean
    'ja': transliterate_function_ja,   # Japanese
    'hi': transliterate_function_hi,  # Hindi
    'bn': transliterate_function_bn  # Bengali
    '''

    # Select the appropriate transliteration function based on the language code
    transliterate_func = transliteration_functions.get(language_code.lower())

    # Check if a valid function was found
    if transliterate_func:
        return transliterate_func(name)
    else:
        raise ValueError(f"Transliteration function for language code '{language_code}' not found.")

# %% [markdown]
# ## Combined Pipeline

# %% [markdown]
# ### List of Supported Languages

# %%
# Combine all lists into one list of supported languages
list_of_supported_languages = {**special_languages,**languages_similar_to_english,**cyrillic_languagues}
print('Number of Supported Languages:' , len(list_of_supported_languages))
# Out:
# Number of Supported Languages: 28

# %%
list_of_supported_languages.values()
# Out:
# dict_values(['Arabic', 'Spanish', 'Portuguese', 'French', 'Italian', 'German', 'Dutch', 'Swedish', 'Danish', 'Norwegian', 'Romanian', 'Polish', 'Czech', 'Slovak', 'Hungarian', 'Turkish', 'Vietnamese', 'Malay', 'Indonesian', 'cyrillic script', 'Russian', 'Ukrainian', 'Bulgarian', 'Mongolian', 'Macedonian', 'Serbian', 'Greek', 'Armenian'])

# %% [markdown]
# ### Detect Language

# %%
from langdetect import detect, DetectorFactory

# Ensure consistent language detection
DetectorFactory.seed = 0

def detect_script(text):
    if re.search(r'[\u0600-\u06ff]', text):
        return 'ar'
    elif re.search(r'[\u4e00-\u9fff]', text):
        return 'zh'
    elif re.search(r'[\u3040-\u309f]', text) or re.search(r'[\u30a0-\u30ff]', text):
        return 'ja'
    elif re.search(r'[\uac00-\ud7af]', text):
        return 'ko'
    elif re.search(r'[\u0400-\u04ff]', text):
        return 'cyrillic'
    else:
        return detect(text)

# %%
### Main Function to Detect Language and Apply the Correct Pipeline

def detect_language_pipeline(name):
    detected_language = detect_script(name)

    if detected_language in languages_similar_to_english :
      # Direct transliteration
      return transliterate_direct(name)

    elif detected_language in cyrillic_languagues :
      # Cyrillic transliteration
      return transliterate_cyrillic(name)

    elif detected_language in special_languages :
      # Special treatment for non-similar languages
      return special_transliterate(name, detected_language)

    else:
      # Direct transliteration
      return transliterate_direct(name)
      #raise ValueError(f"Translation model and tokenizer for country code '{detected_language}' not found.")

# %% [markdown]
# ### Test

# %%
detect_script('أحمد ماجد')
# Out:
# 'ar'

# %%
detect_language_pipeline('مصطفى رؤوف')
# Out:
# 'mustafa raauf'

# %%
# List of names with their languages and expected English versions
special_with_translations = [
    ("محمد هاني", "Arabic", "Mohamed Hany")
]

# Combine all lists into one
names_with_translations = special_with_translations + latin_with_translations + cyrillic_with_translations

# %%
import pandas as pd

# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
transliterated_outputs = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in names_with_translations:
    transliterated_version = detect_language_pipeline(name)
    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    transliterated_outputs.append(transliterated_version)

# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Transliterated Output": transliterated_outputs
})

# %%
# Display the DataFrame
df
# Out:
#       Language          Original Name       Expected English  \
# 0       Arabic              محمد هاني           Mohamed Hany
# 1      Spanish            José García            Jose Garcia
# 2   Portuguese             João Silva             Joao Silva
# 3       French        François Dupont        Francois Dupont
# 4      Italian         Giuseppe Rossi         Giuseppe Rossi
# 5       German          Jürgen Müller          Jurgen Muller
# 6        Dutch       Maarten van Dijk       Maarten van Dijk
# 7      Swedish        Björn Johansson        Bjorn Johansson
# 8       Danish           Søren Larsen           Soren Larsen
# 9    Norwegian          Øyvind Hansen          Oyvind Hansen
# 10    Romanian         Ștefan Popescu         Stefan Popescu
# 11      Polish           Łukasz Nowak           Lukasz Nowak
# 12       Czech             Jiří Novák             Jiri Novak
# 13      Slovak          Ľuboš Horváth          Lubos Horvath
# 14   Hungarian           Árpád Kovács           Arpad Kovacs
# 15     Turkish          Mehmet Yılmaz          Mehmet Yilmaz
# 16  Vietnamese           Nguyễn Văn A           Nguyen Van A
# 17       Malay          Muhammad Amin          Muhammad Amin
# 18  Indonesian             Putri Dewi             Putri Dewi
# 19     Russian         Алексей Иванов         Aleksei Ivanov
# 20   Ukrainian     Олександр Шевченко   Oleksandr Shevchenko
# 21   Bulgarian          Георги Петров          Georgi Petrov
# 22   Mongolian       Батбаяр Сэргэлэн      Batbayar Sergelen
# 23  Macedonian    Александар Стојанов    Aleksandar Stojanov
# 24     Serbian           Никола Тесла           Nikola Tesla
# 25       Greek  Νικόλαος Παπαδόπουλος  Nikolaos Papadopoulos
# 26    Armenian       Արամ Մարտիրոսյան       Aram Martirosyan
#
#     Transliterated Output
# 0           muhammad hani
# 1             Jose Garcia
# 2              Joao Silva
# 3         Francois Dupont
# 4          Giuseppe Rossi
# 5           Jurgen Muller
# 6        Maarten van Dijk
# 7         Bjorn Johansson
# 8            Soren Larsen
# 9           Oyvind Hansen
# 10         Stefan Popescu
# 11           Lukasz Nowak
# 12             Jiri Novak
# 13          Lubos Horvath
# 14           Arpad Kovacs
# 15          Mehmet Yilmaz
# 16           Nguyen Van A
# 17          Muhammad Amin
# 18             Putri Dewi
# 19         Aleksei Ivanov
# 20   Oleksandr Shevchenko
# 21          Georgi Petrov
# 22      Batbaiar Sergelen
# 23    Aleksandar Stojanov
# 24           Nikola Tesla
# 25  Nikolaos Papadopoulos
# 26       Aram Martirosyan

# %% [markdown]
# # <font size="8">Matching</font>

# %% [markdown]
# ## BERT Embeddings Matching

# %%
def get_bert_token_embeddings(name):
    # Tokenize and encode the name
    inputs = bert_tokenizer(name, return_tensors="pt", padding=True, truncation=True)

    # Pass through BERT model
    with torch.no_grad():
        outputs = bert_model(**inputs)

    # Extract the embeddings from the last hidden state
    embeddings = outputs.last_hidden_state.squeeze(0)  # Shape: (sequence_length, hidden_size)
    return embeddings, inputs.input_ids.squeeze(0)  # Return both embeddings and input IDs

def position_aware_similarity(name1, name2):
    # Normalize the input names to lowercase
    name1 = name1.lower()
    name2 = name2.lower()

    # Get token embeddings and input IDs for both names
    embeddings1, input_ids1 = get_bert_token_embeddings(name1)
    embeddings2, input_ids2 = get_bert_token_embeddings(name2)

    # Compute minimum length to compare up to the shorter name
    min_length = min(len(input_ids1), len(input_ids2))

    # Compute cosine similarity for each token at the same position
    similarities = F.cosine_similarity(embeddings1[:min_length], embeddings2[:min_length], dim=1)

    # Compute overall similarity as the mean of token-wise similarities
    overall_similarity = similarities.mean().item()

    # Apply penalties for length and order differences
    length_penalty = abs(len(input_ids1) - len(input_ids2)) / max(len(input_ids1), len(input_ids2))
    order_penalty = (1 - similarities.mean()).item()  # Penalty for order mismatch

    # Combine similarity with penalties
    adjusted_similarity = overall_similarity - length_penalty - order_penalty

    return max(0, adjusted_similarity)  # Ensure similarity does not go below 0

# %%
def bert_match(name1, name2):

    # Normalize the input names to lowercase
    name1 = name1.lower()
    name2 = name2.lower()


    # Get position-aware similarity between the names
    similarity = position_aware_similarity(name1, name2)
    output = round(similarity, 2)

    # Interpret the result
    if similarity > 0.75:
        return True, output
    else:
        return False, output

# %%
# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
transliterated_outputs = []
match_result = []
match_scores = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in names_with_translations:
    transliterated_version = detect_language_pipeline(name)
    match_output, match_score = bert_match(expected, transliterated_version)

    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    transliterated_outputs.append(transliterated_version)
    match_result.append(match_output)
    match_scores.append(match_score)


# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Transliterated Output": transliterated_outputs,
    "Match Result": match_result,
    "Match Score": match_scores
})

# %%
df
# Out:
#       Language          Original Name       Expected English  \
# 0       Arabic              محمد هاني           Mohamed Hany
# 1      Spanish            José García            Jose Garcia
# 2   Portuguese             João Silva             Joao Silva
# 3       French        François Dupont        Francois Dupont
# 4      Italian         Giuseppe Rossi         Giuseppe Rossi
# 5       German          Jürgen Müller          Jurgen Muller
# 6        Dutch       Maarten van Dijk       Maarten van Dijk
# 7      Swedish        Björn Johansson        Bjorn Johansson
# 8       Danish           Søren Larsen           Soren Larsen
# 9    Norwegian          Øyvind Hansen          Oyvind Hansen
# 10    Romanian         Ștefan Popescu         Stefan Popescu
# 11      Polish           Łukasz Nowak           Lukasz Nowak
# 12       Czech             Jiří Novák             Jiri Novak
# 13      Slovak          Ľuboš Horváth          Lubos Horvath
# 14   Hungarian           Árpád Kovács           Arpad Kovacs
# 15     Turkish          Mehmet Yılmaz          Mehmet Yilmaz
# 16  Vietnamese           Nguyễn Văn A           Nguyen Van A
# 17       Malay          Muhammad Amin          Muhammad Amin
# 18  Indonesian             Putri Dewi             Putri Dewi
# 19     Russian         Алексей Иванов         Aleksei Ivanov
# 20   Ukrainian     Олександр Шевченко   Oleksandr Shevchenko
# 21   Bulgarian          Георги Петров          Georgi Petrov
# 22   Mongolian       Батбаяр Сэргэлэн      Batbayar Sergelen
# 23  Macedonian    Александар Стојанов    Aleksandar Stojanov
# 24     Serbian           Никола Тесла           Nikola Tesla
# 25       Greek  Νικόλαος Παπαδόπουλος  Nikolaos Papadopoulos
# 26    Armenian       Արամ Մարտիրոսյան       Aram Martirosyan
#
#     Transliterated Output  Match Result  Match Score
# 0           muhammad hani         False         0.51
# 1             Jose Garcia          True         1.00
# 2              Joao Silva          True         1.00
# 3         Francois Dupont          True         1.00
# 4          Giuseppe Rossi          True         1.00
# 5           Jurgen Muller          True         1.00
# 6        Maarten van Dijk          True         1.00
# 7         Bjorn Johansson          True         1.00
# 8            Soren Larsen          True         1.00
# 9           Oyvind Hansen          True         1.00
# 10         Stefan Popescu          True         1.00
# 11           Lukasz Nowak          True         1.00
# 12             Jiri Novak          True         1.00
# 13          Lubos Horvath          True         1.00
# 14           Arpad Kovacs          True         1.00
# 15          Mehmet Yilmaz          True         1.00
# 16           Nguyen Van A          True         1.00
# 17          Muhammad Amin          True         1.00
# 18             Putri Dewi          True         1.00
# 19         Aleksei Ivanov          True         1.00
# 20   Oleksandr Shevchenko          True         1.00
# 21          Georgi Petrov          True         1.00
# 22      Batbaiar Sergelen          True         0.78
# 23    Aleksandar Stojanov          True         1.00
# 24           Nikola Tesla          True         1.00
# 25  Nikolaos Papadopoulos          True         1.00
# 26       Aram Martirosyan          True         1.00

# %% [markdown]
# ## Phonetics Matching

# %%
from metaphone import doublemetaphone

def metaphone_encode(name):
    # Encode the name using Double Metaphone and select the primary encoding
    return ' '.join(doublemetaphone(word)[0] for word in name.split())

def compare_name(name1, name2):
    # Compare if two names match phonetically
    return metaphone_encode(name1) == metaphone_encode(name2)

# %%
# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
encoded_expected = []
transliterated_outputs = []
encoded_outputs = []
match_result = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in names_with_translations:
    encoded_original = metaphone_encode(expected)
    transliterated_version = detect_language_pipeline(name)
    encoded_transliterated = metaphone_encode(transliterated_version)
    match_output = compare_name(encoded_original, encoded_transliterated)

    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    encoded_expected.append(encoded_original)
    transliterated_outputs.append(transliterated_version)
    encoded_outputs.append(encoded_transliterated)
    match_result.append(match_output)


# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Encoded Expected": encoded_expected,
    "Transliterated Output": transliterated_outputs,
    "Encoded Transliterated": encoded_outputs,
    "Match Result": match_result
})

# %%
df
# Out:
#       Language          Original Name       Expected English Encoded Expected  \
# 0       Arabic              محمد هاني           Mohamed Hany          MHMT HN
# 1      Spanish            José García            Jose Garcia           JS KRS
# 2   Portuguese             João Silva             Joao Silva            J SLF
# 3       French        François Dupont        Francois Dupont        FRNK TPNT
# 4      Italian         Giuseppe Rossi         Giuseppe Rossi           JSP RS
# 5       German          Jürgen Müller          Jurgen Muller         JRJN MLR
# 6        Dutch       Maarten van Dijk       Maarten van Dijk       MRTN FN TK
# 7      Swedish        Björn Johansson        Bjorn Johansson       PJRN JHNSN
# 8       Danish           Søren Larsen           Soren Larsen         SRN LRSN
# 9    Norwegian          Øyvind Hansen          Oyvind Hansen        AFNT HNSN
# 10    Romanian         Ștefan Popescu         Stefan Popescu        STFN PPSK
# 11      Polish           Łukasz Nowak           Lukasz Nowak           LKS NK
# 12       Czech             Jiří Novák             Jiri Novak           JR NFK
# 13      Slovak          Ľuboš Horváth          Lubos Horvath         LPS HRF0
# 14   Hungarian           Árpád Kovács           Arpad Kovacs        ARPT KFKS
# 15     Turkish          Mehmet Yılmaz          Mehmet Yilmaz         MMT ALMS
# 16  Vietnamese           Nguyễn Văn A           Nguyen Van A         NKN FN A
# 17       Malay          Muhammad Amin          Muhammad Amin         MHMT AMN
# 18  Indonesian             Putri Dewi             Putri Dewi            PTR T
# 19     Russian         Алексей Иванов         Aleksei Ivanov        ALKS AFNF
# 20   Ukrainian     Олександр Шевченко   Oleksandr Shevchenko    ALKSNTR XFXNK
# 21   Bulgarian          Георги Петров          Georgi Petrov         JRJ PTRF
# 22   Mongolian       Батбаяр Сэргэлэн      Batbayar Sergelen       PTPR SRJLN
# 23  Macedonian    Александар Стојанов    Aleksandar Stojanov    ALKSNTR STJNF
# 24     Serbian           Никола Тесла           Nikola Tesla          NKL TSL
# 25       Greek  Νικόλαος Παπαδόπουλος  Nikolaos Papadopoulos      NKLS PPTPLS
# 26    Armenian       Արամ Մարտիրոսյան       Aram Martirosyan       ARM MRTRSN
#
#     Transliterated Output Encoded Transliterated  Match Result
# 0           muhammad hani                MHMT HN          True
# 1             Jose Garcia                 JS KRS          True
# 2              Joao Silva                  J SLF          True
# 3         Francois Dupont              FRNK TPNT          True
# 4          Giuseppe Rossi                 JSP RS          True
# 5           Jurgen Muller               JRJN MLR          True
# 6        Maarten van Dijk             MRTN FN TK          True
# 7         Bjorn Johansson             PJRN JHNSN          True
# 8            Soren Larsen               SRN LRSN          True
# 9           Oyvind Hansen              AFNT HNSN          True
# 10         Stefan Popescu              STFN PPSK          True
# 11           Lukasz Nowak                 LKS NK          True
# 12             Jiri Novak                 JR NFK          True
# 13          Lubos Horvath               LPS HRF0          True
# 14           Arpad Kovacs              ARPT KFKS          True
# 15          Mehmet Yilmaz               MMT ALMS          True
# 16           Nguyen Van A               NKN FN A          True
# 17          Muhammad Amin               MHMT AMN          True
# 18             Putri Dewi                  PTR T          True
# 19         Aleksei Ivanov              ALKS AFNF          True
# 20   Oleksandr Shevchenko          ALKSNTR XFXNK          True
# 21          Georgi Petrov               JRJ PTRF          True
# 22      Batbaiar Sergelen             PTPR SRJLN          True
# 23    Aleksandar Stojanov          ALKSNTR STJNF          True
# 24           Nikola Tesla                NKL TSL          True
# 25  Nikolaos Papadopoulos            NKLS PPTPLS          True
# 26       Aram Martirosyan             ARM MRTRSN          True

# %% [markdown]
# ## Combined Matching

# %%
def combined_match(name1, name2):

    # Normalize the input names to metaphone
    name1 = metaphone_encode(name1)
    name2 = metaphone_encode(name2)

    # Get position-aware similarity between the names
    similarity = position_aware_similarity(name1, name2)
    output = round(similarity, 2)

    # Interpret the result
    if similarity > 0.75:
        return True, output
    else:
        return False, output

# %%
# Create lists to store data for the DataFrame
languages = []
original_names = []
expected_english_versions = []
encoded_expected = []
transliterated_outputs = []
encoded_outputs = []
match_result = []
match_scores = []

# Loop through each name, perform the transliteration, and store in lists
for name, language, expected in names_with_translations:
    encoded_original = metaphone_encode(expected)
    transliterated_version = detect_language_pipeline(name)
    encoded_transliterated = metaphone_encode(transliterated_version)
    match_output, match_score = combined_match(encoded_original, encoded_transliterated)
    #Fill the df
    languages.append(language)
    original_names.append(name)
    expected_english_versions.append(expected)
    encoded_expected.append(encoded_original)
    transliterated_outputs.append(transliterated_version)
    encoded_outputs.append(encoded_transliterated)
    match_result.append(match_output)
    match_scores.append(match_score)


# Create a Pandas DataFrame
df = pd.DataFrame({
    "Language": languages,
    "Original Name": original_names,
    "Expected English": expected_english_versions,
    "Encoded Expected": encoded_expected,
    "Transliterated Output": transliterated_outputs,
    "Encoded Transliterated": encoded_outputs,
    "Match Result": match_result,
    "Match Score": match_scores
})

# %%
df
# Out:
#       Language          Original Name       Expected English Encoded Expected  \
# 0       Arabic              محمد هاني           Mohamed Hany          MHMT HN
# 1      Spanish            José García            Jose Garcia           JS KRS
# 2   Portuguese             João Silva             Joao Silva            J SLF
# 3       French        François Dupont        Francois Dupont        FRNK TPNT
# 4      Italian         Giuseppe Rossi         Giuseppe Rossi           JSP RS
# 5       German          Jürgen Müller          Jurgen Muller         JRJN MLR
# 6        Dutch       Maarten van Dijk       Maarten van Dijk       MRTN FN TK
# 7      Swedish        Björn Johansson        Bjorn Johansson       PJRN JHNSN
# 8       Danish           Søren Larsen           Soren Larsen         SRN LRSN
# 9    Norwegian          Øyvind Hansen          Oyvind Hansen        AFNT HNSN
# 10    Romanian         Ștefan Popescu         Stefan Popescu        STFN PPSK
# 11      Polish           Łukasz Nowak           Lukasz Nowak           LKS NK
# 12       Czech             Jiří Novák             Jiri Novak           JR NFK
# 13      Slovak          Ľuboš Horváth          Lubos Horvath         LPS HRF0
# 14   Hungarian           Árpád Kovács           Arpad Kovacs        ARPT KFKS
# 15     Turkish          Mehmet Yılmaz          Mehmet Yilmaz         MMT ALMS
# 16  Vietnamese           Nguyễn Văn A           Nguyen Van A         NKN FN A
# 17       Malay          Muhammad Amin          Muhammad Amin         MHMT AMN
# 18  Indonesian             Putri Dewi             Putri Dewi            PTR T
# 19     Russian         Алексей Иванов         Aleksei Ivanov        ALKS AFNF
# 20   Ukrainian     Олександр Шевченко   Oleksandr Shevchenko    ALKSNTR XFXNK
# 21   Bulgarian          Георги Петров          Georgi Petrov         JRJ PTRF
# 22   Mongolian       Батбаяр Сэргэлэн      Batbayar Sergelen       PTPR SRJLN
# 23  Macedonian    Александар Стојанов    Aleksandar Stojanov    ALKSNTR STJNF
# 24     Serbian           Никола Тесла           Nikola Tesla          NKL TSL
# 25       Greek  Νικόλαος Παπαδόπουλος  Nikolaos Papadopoulos      NKLS PPTPLS
# 26    Armenian       Արամ Մարտիրոսյան       Aram Martirosyan       ARM MRTRSN
#
#     Transliterated Output Encoded Transliterated  Match Result  Match Score
# 0           muhammad hani                MHMT HN          True          1.0
# 1             Jose Garcia                 JS KRS          True          1.0
# 2              Joao Silva                  J SLF          True          1.0
# 3         Francois Dupont              FRNK TPNT          True          1.0
# 4          Giuseppe Rossi                 JSP RS          True          1.0
# 5           Jurgen Muller               JRJN MLR          True          1.0
# 6        Maarten van Dijk             MRTN FN TK          True          1.0
# 7         Bjorn Johansson             PJRN JHNSN          True          1.0
# 8            Soren Larsen               SRN LRSN          True          1.0
# 9           Oyvind Hansen              AFNT HNSN          True          1.0
# 10         Stefan Popescu              STFN PPSK          True          1.0
# 11           Lukasz Nowak                 LKS NK          True          1.0
# 12             Jiri Novak                 JR NFK          True          1.0
# 13          Lubos Horvath               LPS HRF0          True          1.0
# 14           Arpad Kovacs              ARPT KFKS          True          1.0
# 15          Mehmet Yilmaz               MMT ALMS          True          1.0
# 16           Nguyen Van A               NKN FN A          True          1.0
# 17          Muhammad Amin               MHMT AMN          True          1.0
# 18             Putri Dewi                  PTR T          True          1.0
# 19         Aleksei Ivanov              ALKS AFNF          True          1.0
# 20   Oleksandr Shevchenko          ALKSNTR XFXNK          True          1.0
# 21          Georgi Petrov               JRJ PTRF          True          1.0
# 22      Batbaiar Sergelen             PTPR SRJLN          True          1.0
# 23    Aleksandar Stojanov          ALKSNTR STJNF          True          1.0
# 24           Nikola Tesla                NKL TSL          True          1.0
# 25  Nikolaos Papadopoulos            NKLS PPTPLS          True          1.0
# 26       Aram Martirosyan             ARM MRTRSN          True          1.0

# %% [markdown]
# # <font size="8">Input Processing</font>

# %% [markdown]
# ## Text Normalization

# %%
#using Regular Expression to normalize the names
import re
def normalize_text(text):
    # Check if the input name is not in English
    if not text.isascii():
      return text
    else:
      # Convert to lowercase
      text = text.lower()
      # Remove special characters and numbers
      text = re.sub(r'[^a-zA-Z\s]', '', text)
      # Remove extra spaces
      text = re.sub(r'\s+', ' ', text).strip()
      return text

# %% [markdown]
# ## Handling Last Names

# %%
def rearrange_name(name):
    # Check if the input name is not in English
    if not name.isascii():
      return name
    else:
      if ',' in name:
          last_name, first_names = name.split(',', 1)
          rearranged_name = f"{first_names.strip()} {last_name.strip()}"
      else:
          rearranged_name = name.strip()
      return rearranged_name

input_name = "Loutfi, Ahmed Maged"
corrected_name = rearrange_name(input_name)
print("Rearranged name:", corrected_name)
# Out:
# Rearranged name: Ahmed Maged Loutfi

# %%
def print_ex(name1, name2):
    # Rearrange if necessary
    r_name1 = rearrange_name(name1)
    r_name2 = rearrange_name(name2)
    # Translate if necessary
    translated_name1 = detect_language_pipeline(r_name1)
    translated_name2 = detect_language_pipeline(r_name2)

    # Print statements
    print(f" Input Name: {name1}\n", f"Rearranged: {r_name1}\n", f"Script: {detect_script(r_name1)}\n", f"Translated: {translated_name1}\n",  f"Encoded: {metaphone_encode(translated_name1)}\n")
    print(f" Banned Name: {name2}\n", f"Rearranged: {r_name2}\n", f"Script: {detect_script(r_name2)}\n", f"Translated: {translated_name2}\n", f"Encoded: {metaphone_encode(translated_name2)}\n")

    # Comparison
    is_match = compare_name(translated_name1, translated_name2)
    print(f" Match Result: {is_match}")

# %%
print_ex('Андрей  Иванов',
         'اندري ايفانوف	')
# Out:
#  Input Name: Андрей  Иванов
#  Rearranged: Андрей  Иванов
#  Script: cyrillic
#  Translated: Andrei  Ivanov
#  Encoded: ANTR AFNF
#
#  Banned Name: اندري ايفانوف
#  Rearranged: اندري ايفانوف
#  Script: ar
#  Translated: andri ayfanuf
#  Encoded: ANTR AFNF
#
#  Match Result: True

# %% [markdown]
# # <font size="8">Banned Names</font>

# %%
# Predefined list of banned names
banned_names = [row[-1] for row in names_with_translations]
processed_banned_names = [detect_language_pipeline(normalize_text(rearrange_name(name))) for name in banned_names]
processed_banned_names
# Out:
# ['mohamed hany',
#  'jose garcia',
#  'joao silva',
#  'francois dupont',
#  'giuseppe rossi',
#  'jurgen muller',
#  'maarten van dijk',
#  'bjorn johansson',
#  'soren larsen',
#  'oyvind hansen',
#  'stefan popescu',
#  'lukasz nowak',
#  'jiri novak',
#  'lubos horvath',
#  'arpad kovacs',
#  'mehmet yilmaz',
#  'nguyen van a',
#  'muhammad amin',
#  'putri dewi',
#  'aleksei ivanov',
#  'oleksandr shevchenko',
#  'georgi petrov',
#  'batbayar sergelen',
#  'aleksandar stojanov',
#  'nikola tesla',
#  'nikolaos papadopoulos',
#  'aram martirosyan']

# %% [markdown]
# # <font size="8">GUI Functions</font>

# %% [markdown]
# ## Combined Matching

# %%
def is_match_combined(input):
    input_name = detect_language_pipeline(normalize_text(rearrange_name(input)))
    results = []
    # If single input name, compare it to predefined banned names
    for name in banned_names:
        banned_name = detect_language_pipeline(normalize_text(rearrange_name(name)))
        is_match_flag, match_score = combined_match(input_name, banned_name)
        results.append([name, match_score, is_match_flag])

    # Get the highest matching score from the predefined list
    best_match = max(results, key=lambda x: x[1])

    # Return the best match result and whether it passed the threshold
    return best_match[2],best_match[:2]

# %%
def match_names_combined(input_name, csv_file=None):
  if input_name:
    # Return the best match result and whether it passed the threshold
    flag, output = is_match_combined(input_name)
    if flag:
      return f"Match Found.\nName: {output[0]}.", None
    else:
      return f"No Match Found.", None

  if csv_file:
    results = []
    names_df = pd.read_csv(csv_file)  # Read the CSV directly from the uploaded file object
    for name in names_df['name']:
        bol, match_result = is_match_combined(name)  # Use is_match function for each name
        results.append([name, bol, match_result[0]])

    # Save results as CSV
    result_df = pd.DataFrame(results, columns=["Name", "Match Result", "Best Match"])
    result_csv = "/tmp/result.csv"
    result_df.to_csv(result_csv, index=False)

    # Count how many True matches
    true_matches = result_df['Match Result'].sum()
    return f"Total Matches Found: {true_matches}", result_csv

# %%
import gradio as gr

# Define the Gradio interface
interface_combined = gr.Interface(
    fn=match_names_combined,
    inputs=[
        gr.Textbox(lines=1, placeholder="Enter a name", label="Input Name (leave blank if uploading CSV)"),
        gr.File(label="Upload CSV with Names")
    ],
    outputs=[
        gr.Textbox(label="Output"),  # For text input output
        gr.File(label="Download Result CSV")  # For CSV output
    ],
    title="Name Matcher Model",
    description="Enter a name or upload a CSV file with names to check if there is a match against the banned names."
)

# %% [markdown]
# ## Phonetics Matching

# %%
def double_metaphone_encoding(name):
    # Get primary and secondary encodings from Double Metaphone
    return doublemetaphone(name)

def compare_double_metaphone(name1, name2):
    # Get Double Metaphone encodings for both names
    name1_primary, name1_secondary = double_metaphone_encoding(name1)
    name2_primary, name2_secondary = double_metaphone_encoding(name2)

    # Initialize match score
    score = 0.0

    # Compare primary encodings
    if name1_primary == name2_primary:
        score += 1.0  # Exact primary match

    # Compare secondary encodings (only if primary doesn't match)
    elif name1_secondary == name2_secondary:
        score += 0.75  # Secondary match

    return score

def compare_full_name(full_name1, full_name2):
    # Split names into parts (assuming format: First Middle Last)
    name_parts1 = full_name1.split()
    name_parts2 = full_name2.split()

    # Make sure both names have the same number of parts (add empty strings if necessary)
    while len(name_parts1) < len(name_parts2):
        name_parts1.append("")
    while len(name_parts2) < len(name_parts1):
        name_parts2.append("")

    total_score = 0.0
    parts_count = len(name_parts1)  # Number of name parts

    # Compare each part (first, middle, last names) using Double Metaphone
    for part1, part2 in zip(name_parts1, name_parts2):
        total_score += compare_double_metaphone(part1, part2)

    # Calculate average match score
    final_score = total_score / parts_count

    return final_score

# %%
def is_match(input):
    input_name = detect_language_pipeline(normalize_text(rearrange_name(input)))
    results = []
    # If single input name, compare it to predefined banned names
    for name in banned_names:
        banned_name = detect_language_pipeline(normalize_text(rearrange_name(name)))
        match_score = compare_full_name(input_name, banned_name)
        is_match_flag = match_score >= 0.9
        results.append([name, match_score, is_match_flag])

    # Get the highest matching score from the predefined list
    best_match = max(results, key=lambda x: x[1])

    # Return the best match result and whether it passed the threshold
    return best_match[2],best_match[:2]

# %%
def match_names(input_name, csv_file=None):
  if input_name:
    # Return the best match result and whether it passed the threshold
    flag, output = is_match(input_name)
    if flag:
      return f"Match Found.\nName: {output[0]}.", None
    else:
      return f"No Match Found.", None

  if csv_file:
    results = []
    names_df = pd.read_csv(csv_file)  # Read the CSV directly from the uploaded file object
    for name in names_df['name']:
        bol, match_result = is_match(name)  # Use is_match function for each name
        results.append([name, bol, match_result[0]])

    # Save results as CSV
    result_df = pd.DataFrame(results, columns=["Name", "Match Result", "Best Match"])
    result_csv = "/tmp/result.csv"
    result_df.to_csv(result_csv, index=False)

    # Count how many True matches
    true_matches = result_df['Match Result'].sum()
    return f"Total Matches Found: {true_matches}", result_csv

# %%
import gradio as gr

# Define the Gradio interface
interface = gr.Interface(
    fn=match_names,
    inputs=[
        gr.Textbox(lines=1, placeholder="Enter a name", label="Input Name (leave blank if uploading CSV)"),
        gr.File(label="Upload CSV with Names")
    ],
    outputs=[
        gr.Textbox(label="Output"),  # For text input output
        gr.File(label="Download Result CSV")  # For CSV output
    ],
    title="Name Matcher Model",
    description="Enter a name or upload a CSV file with names to check if there is a match against the banned names."
)

# %% [markdown]
# # <font size="8">Gradio Interface & API (Combined Matching)</font>
# # <font size="5">## More Accurate but too much processing time >> Not suitable for production level</font>

# %%
# Launch the interface
interface_combined.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://12f07a8b55846a7d84.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://12f07a8b55846a7d84.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
[row[0] for row in names_with_translations]
# Out:
# ['محمد هاني',
#  'José García',
#  'João Silva',
#  'François Dupont',
#  'Giuseppe Rossi',
#  'Jürgen Müller',
#  'Maarten van Dijk',
#  'Björn Johansson',
#  'Søren Larsen',
#  'Øyvind Hansen',
#  'Ștefan Popescu',
#  'Łukasz Nowak',
#  'Jiří Novák',
#  'Ľuboš Horváth',
#  'Árpád Kovács',
#  'Mehmet Yılmaz',
#  'Nguyễn Văn A',
#  'Muhammad Amin',
#  'Putri Dewi',
#  'Алексей Иванов',
#  'Олександр Шевченко',
#  'Георги Петров',
#  'Батбаяр Сэргэлэн',
#  'Александар Стојанов',
#  'Никола Тесла',
#  'Νικόλαος Παπαδόπουλος',
#  'Արամ Մարտիրոսյան']

# %% [markdown]
# # <font size="8">Gradio Interface & API (Phonetics Matching)</font>
# # <font size="5">## Slightly Less Accurate but much less processing time >> Suitable for production level</font>

# %%
# Launch the interface
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e08b9e949cce89e9d5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e08b9e949cce89e9d5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from gradio_client import Client, handle_file

client = Client("https://e08b9e949cce89e9d5.gradio.live/")
result = client.predict(
		input_name="  اليكسي ايفانوف ",
		csv_file=None,
		api_name="/predict"
)
print(result)
# Out:
# Loaded as API: https://e08b9e949cce89e9d5.gradio.live/ ✔
# ('Match Found.\nName: Aleksei Ivanov.', None)
